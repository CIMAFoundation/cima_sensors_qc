# %% [markdown]
# # risicolive_QC interactive notebook

# %%
import risicolive_QC as qc
import pandas as pd

# %% [markdown]
# ---
# ## **Settings**
# All DEFAUL settings are placed in the **config.json** file:
# 1. *INFO*: contains information on time step, unique identifier for the single station (*KEY_STATION*) and variables;
# 2. *TEST*: contains information for tests.
#     - *WINDOW*: sliding window
#     - *VARS_CHECK*: variables checked for the complete_test
#     - *VARS_CONS*: variables checked for the consistency_test
#     - *RANGES*: ranges checked for the range_test
#     - *STEPS*: steps checked for the step_test
#     - *VARIATIONS*: variations checked for the time_persistence_test. These variations are controlled in a specific range of values
#
# These information can be accessed by DEFAULT. The user can also modified these info, following the DEFAULT structure (see examples below).

# %%
qc.DEFAULT['INFO']
# Out:
# {'DT': '10min',
#  'KEY_STATION': 'station_id',
#  'VARS': {'t': {'info': 'temperature', 'um': 'C'},
#   'h': {'info': 'humidity', 'um': '.'},
#   'p': {'info': 'precipitation', 'um': 'mm/dt'},
#   'ws': {'info': 'wind speed', 'um': 'm/s'},
#   'wd': {'info': 'wind direction', 'um': 'deg'}}}

# %%
qc.DEFAULT['TEST']
# Out:
# {'WINDOW': 3,
#  'VARS_CHECK': ['t', 'h', 'p', 'ws', 'wd'],
#  'VARS_CONS': ['ws', 'wd'],
#  'RANGES': {'t': [-30, 50],
#   'h': [0, 100],
#   'p': [0, 400],
#   'ws': [0, 75],
#   'wd': [0, 360]},
#  'STEPS': {'t': 2, 'h': 10, 'ws': 10},
#  'VARIATIONS': {'t': [0.01, -30, 50],
#   'h': [0.01, 0, 95],
#   'ws': [0.01, 0.1, 75]}}

# %% [markdown]
# ---
# ## **Example**

# %%
## Data for all stations of RISICO Live, for a single hour
df_allStations = pd.read_csv('./test/test.csv')
df_allStations
# Out:
#       station_id                       date        t        h    p       ws  \
# 0              1  2017-06-01 00:00:00+00:00  16.4000  63.0000  0.0  1.20000
# 1              1  2017-06-01 00:10:00+00:00  16.6000  59.0000  0.0  1.50000
# 2              1  2017-06-01 00:20:00+00:00  16.6000  59.0000  0.0  0.80000
# 3              1  2017-06-01 00:30:00+00:00  16.9000  59.0000  0.0  1.60000
# 4              1  2017-06-01 00:40:00+00:00  17.0000  59.0000  0.0  0.60000
# ...          ...                        ...      ...      ...  ...      ...
# 3679         614  2017-06-01 00:10:00+00:00  20.7833  86.3333  NaN  1.16667
# 3680         614  2017-06-01 00:20:00+00:00  20.7667  86.6667  NaN  1.33333
# 3681         614  2017-06-01 00:30:00+00:00  20.7500  87.0000  NaN  1.50000
# 3682         614  2017-06-01 00:40:00+00:00  20.7333  87.3333  NaN  1.66667
# 3683         614  2017-06-01 00:50:00+00:00  20.7167  87.6667  NaN  1.83333
#
#          wd
# 0     157.0
# 1     149.0
# 2      88.0
# 3     358.0
# 4      27.0
# ...     ...
# 3679   31.0
# 3680   31.0
# 3681   31.0
# 3682   31.0
# 3683   31.0
#
# [3684 rows x 7 columns]

# %%
## TEST ON A SINGLE STATION: DEFAULT CONFIGURATION
# get data for a single station
df_station = df_allStations[df_allStations[qc.DEFAULT['INFO']['KEY_STATION']]==46]
# perform tests on single station
df_station_checked = qc.check_stations(df_station)
df_station_checked
# Out:
#      station_id                       date        t   h    p   ws   wd   QC  \
# 270          46  2017-06-01 00:00:00+00:00  10.9000 NaN  0.0  0.0  0.0  NaN
# 271          46  2017-06-01 00:10:00+00:00  10.9333 NaN  NaN  0.0  0.0  NaN
# 272          46  2017-06-01 00:20:00+00:00  10.9667 NaN  0.0  0.0  0.0  0.0
# 273          46  2017-06-01 00:30:00+00:00  11.0000 NaN  0.0  0.0  0.0  0.0
# 274          46  2017-06-01 00:40:00+00:00  10.9333 NaN  0.0  0.0  0.0  0.0
# 275          46  2017-06-01 00:50:00+00:00  10.8667 NaN  0.0  0.0  0.0  0.0
#
#        QC_label
# 270        none
# 271        none
# 272  incomplete
# 273  incomplete
# 274  incomplete
# 275  incomplete

# %%
# TEST ON A SINGLE STATION: CHANGE CONFIG
# Some info are specified by user (e.g. variables checked by complete_test, ranges checked by range_test). 
# The missing info are added by default configuration
config_new = {'VARS_CHECK':['t'], 'RANGES':{'t':[0, 50]}, 'VARIATIONS':{'t':[1,-10,50]}}
df_station_checked = qc.check_stations(df_station, config=config_new)
df_station_checked
# Out:
#      station_id                       date        t   h    p   ws   wd   QC  \
# 270          46  2017-06-01 00:00:00+00:00  10.9000 NaN  0.0  0.0  0.0  NaN
# 271          46  2017-06-01 00:10:00+00:00  10.9333 NaN  NaN  0.0  0.0  NaN
# 272          46  2017-06-01 00:20:00+00:00  10.9667 NaN  0.0  0.0  0.0  4.0
# 273          46  2017-06-01 00:30:00+00:00  11.0000 NaN  0.0  0.0  0.0  4.0
# 274          46  2017-06-01 00:40:00+00:00  10.9333 NaN  0.0  0.0  0.0  4.0
# 275          46  2017-06-01 00:50:00+00:00  10.8667 NaN  0.0  0.0  0.0  4.0
#
#        QC_label
# 270        none
# 271        none
# 272  suspicious
# 273  suspicious
# 274  suspicious
# 275  suspicious

# %%
# TEST ON ALL STATIONS
# if the dataframe contains more than one station, the tests are applied to each station
df_allStations_checked = qc.check_stations(df_allStations)
df_allStations_checked
# Out:
#       station_id                       date        t        h    p       ws  \
# 0              1  2017-06-01 00:00:00+00:00  16.4000  63.0000  0.0  1.20000
# 1              1  2017-06-01 00:10:00+00:00  16.6000  59.0000  0.0  1.50000
# 2              1  2017-06-01 00:20:00+00:00  16.6000  59.0000  0.0  0.80000
# 3              1  2017-06-01 00:30:00+00:00  16.9000  59.0000  0.0  1.60000
# 4              1  2017-06-01 00:40:00+00:00  17.0000  59.0000  0.0  0.60000
# ...          ...                        ...      ...      ...  ...      ...
# 3679         614  2017-06-01 00:10:00+00:00  20.7833  86.3333  NaN  1.16667
# 3680         614  2017-06-01 00:20:00+00:00  20.7667  86.6667  NaN  1.33333
# 3681         614  2017-06-01 00:30:00+00:00  20.7500  87.0000  NaN  1.50000
# 3682         614  2017-06-01 00:40:00+00:00  20.7333  87.3333  NaN  1.66667
# 3683         614  2017-06-01 00:50:00+00:00  20.7167  87.6667  NaN  1.83333
#
#          wd   QC    QC_label
# 0     157.0  NaN        none
# 1     149.0  NaN        none
# 2      88.0  5.0        good
# 3     358.0  4.0  suspicious
# 4      27.0  4.0  suspicious
# ...     ...  ...         ...
# 3679   31.0  NaN        none
# 3680   31.0  0.0  incomplete
# 3681   31.0  0.0  incomplete
# 3682   31.0  0.0  incomplete
# 3683   31.0  0.0  incomplete
#
# [3684 rows x 9 columns]
