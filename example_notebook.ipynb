# %% [markdown]
# # risicolive_QC interactive notebook

# %%
import risicolive_QC as qc
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ## **Settings**
# All DEFAUL settings are placed in the **config.json** file:
# 1. *INFO*: contains information on time step, unique identifier for the single station (*KEY_STATION*) and variables;
# 2. *TEST*: contains information for tests.
#     - *WINDOW*: sliding window
#     - *VARS_CHECK*: variables checked for the complete_test
#     - *VARS_CONS*: variables checked for the consistency_test
#     - *RANGES*: ranges checked for the range_test
#     - *STEPS*: steps checked for the step_test
#     - *VARIATIONS*: variations checked for the time_persistence_test. These variations are controlled in a specific range of values
#
# These information can be accessed by DEFAULT. The user can also modified these info, following the DEFAULT structure (see examples below).

# %%
qc.INFO
# Out:
# {'DT': '10min',
#  'KEY_STATION': 'station_id',
#  'VARS': {'t': {'info': 'temperature', 'um': 'C'},
#   'h': {'info': 'humidity', 'um': '.'},
#   'p': {'info': 'precipitation', 'um': 'mm/dt'},
#   'ws': {'info': 'wind speed', 'um': 'm/s'},
#   'wd': {'info': 'wind direction', 'um': 'deg'}}}

# %%
qc.DEFAULT
# Out:
# {'VARS_CHECK': ['t', 'h', 'p', 'ws'],
#  'VARS_CONS': ['ws', 'wd'],
#  'RANGES': {'t': [-30, 50],
#   'h': [0, 100],
#   'p': [0, 400],
#   'ws': [0, 75],
#   'wd': [0, 360]},
#  'STEPS': {'t': 2, 'h': 10},
#  'WINDOW': 3,
#  'VARIATIONS': {'t': [0.01, -30, 50], 'h': [0.01, 0, 95], 'ws': [0.01, 0, 75]}}

# %% [markdown]
# ---
# ## **Example**

# %%
df_TEST = pd.read_csv('test/75200.csv', index_col=0)
df_TEST
# Out:
#                             p          t     h        ws     wd        sm  \
# date
# 2022-09-29 11:50:00+00:00 NaN  21.400000  64.0  8.400001  206.0  0.535962
# 2022-09-29 12:00:00+00:00 NaN  21.400000  67.0  6.700000  211.0  0.535636
# 2022-09-29 12:10:00+00:00 NaN  21.300001  61.0  7.800000  212.0  0.535309
# 2022-09-29 12:20:00+00:00 NaN  21.300001  63.0  8.900001  211.0  0.534983
# 2022-09-29 12:30:00+00:00 NaN  21.600000  65.0  7.600000  209.0  0.534657
# ...                        ..        ...   ...       ...    ...       ...
# 2022-09-30 11:10:00+00:00 NaN        NaN   NaN       NaN    NaN  0.514102
# 2022-09-30 11:20:00+00:00 NaN        NaN   NaN       NaN    NaN  0.514102
# 2022-09-30 11:30:00+00:00 NaN        NaN   NaN       NaN    NaN  0.514102
# 2022-09-30 11:40:00+00:00 NaN        NaN   NaN       NaN    NaN  0.514102
# 2022-09-30 11:50:00+00:00 NaN        NaN   NaN       NaN    NaN  0.514102
#
#                                 gsi      igsi  pheno_phase  grass_phase  \
# date
# 2022-09-29 11:50:00+00:00  0.533734  0.525523          5.0          3.0
# 2022-09-29 12:00:00+00:00  0.533734  0.525523          5.0          3.0
# 2022-09-29 12:10:00+00:00  0.533734  0.525523          5.0          3.0
# 2022-09-29 12:20:00+00:00  0.533734  0.525523          5.0          3.0
# 2022-09-29 12:30:00+00:00  0.533734  0.525523          5.0          3.0
# ...                             ...       ...          ...          ...
# 2022-09-30 11:10:00+00:00  0.533734  0.525523          5.0          3.0
# 2022-09-30 11:20:00+00:00  0.533734  0.525523          5.0          3.0
# 2022-09-30 11:30:00+00:00  0.533734  0.525523          5.0          3.0
# 2022-09-30 11:40:00+00:00  0.533734  0.525523          5.0          3.0
# 2022-09-30 11:50:00+00:00  0.533734  0.525523          5.0          3.0
#
#                            moisture  intensity      ros  wind_effect
# date
# 2022-09-29 11:50:00+00:00   14.2233    386.973  196.168      2.74243
# 2022-09-29 12:00:00+00:00       NaN        NaN      NaN          NaN
# 2022-09-29 12:10:00+00:00       NaN        NaN      NaN          NaN
# 2022-09-29 12:20:00+00:00       NaN        NaN      NaN          NaN
# 2022-09-29 12:30:00+00:00       NaN        NaN      NaN          NaN
# ...                             ...        ...      ...          ...
# 2022-09-30 11:10:00+00:00       NaN        NaN      NaN          NaN
# 2022-09-30 11:20:00+00:00       NaN        NaN      NaN          NaN
# 2022-09-30 11:30:00+00:00       NaN        NaN      NaN          NaN
# 2022-09-30 11:40:00+00:00       NaN        NaN      NaN          NaN
# 2022-09-30 11:50:00+00:00       NaN        NaN      NaN          NaN
#
# [145 rows x 14 columns]

# %%
# TEST ON A SINGLE STATION: DEFAULT
df_check = qc.quality_check(df_TEST)
df_check
# Out:
#                            QC    QC_LABEL
# date
# 2022-09-29 11:50:00+00:00   2  INCOMPLETE
# 2022-09-29 12:00:00+00:00  10  INCOMPLETE
# 2022-09-29 12:10:00+00:00  26  INCOMPLETE
# 2022-09-29 12:20:00+00:00  26  INCOMPLETE
# 2022-09-29 12:30:00+00:00  26  INCOMPLETE
# ...                        ..         ...
# 2022-09-30 11:10:00+00:00   2  INCOMPLETE
# 2022-09-30 11:20:00+00:00   2  INCOMPLETE
# 2022-09-30 11:30:00+00:00   2  INCOMPLETE
# 2022-09-30 11:40:00+00:00   2  INCOMPLETE
# 2022-09-30 11:50:00+00:00   2  INCOMPLETE
#
# [145 rows x 2 columns]

# %%
# TEST ON A SINGLE STATION: CHANGE CONFIG
# Some info are specified by user (e.g. variables checked by complete_test, ranges checked by range_test). 
# The missing info are added by default configuration
settings_new = {'VARS_CHECK':['t'], 'RANGES':{'t':[0, 50]}, 'VARIATIONS':{'t':[1,-10,50]}}
df_check_new = qc.quality_check(df_TEST, settings=settings_new)
df_check_new
# Out:
#                            QC    QC_LABEL
# date
# 2022-09-29 11:50:00+00:00   7  INCOMPLETE
# 2022-09-29 12:00:00+00:00  15  INCOMPLETE
# 2022-09-29 12:10:00+00:00  15  INCOMPLETE
# 2022-09-29 12:20:00+00:00  15  INCOMPLETE
# 2022-09-29 12:30:00+00:00  15  INCOMPLETE
# ...                        ..         ...
# 2022-09-30 11:10:00+00:00   2  INCOMPLETE
# 2022-09-30 11:20:00+00:00   2  INCOMPLETE
# 2022-09-30 11:30:00+00:00   2  INCOMPLETE
# 2022-09-30 11:40:00+00:00   2  INCOMPLETE
# 2022-09-30 11:50:00+00:00   2  INCOMPLETE
#
# [145 rows x 2 columns]
